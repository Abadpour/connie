# %% [markdown]
# # Visual tester for Connie
# [https://github.com/Abadpour/Connie](https://github.com/Abadpour/Connie)

# %% [markdown]
# ## Imports

# %%
from connie2de import Connie2de
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Execution

# %%
Connie2de.initialize()
Connie2de('void',3).execute().visualize('input').visualize('classification').visualize('clusters').visualize('fnc').visualize('pn')
# Out:
# <connie2de.Connie2de instance at 0x0000000003CDD808>
